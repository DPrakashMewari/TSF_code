# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
 iris = pd.read_csv("C:\\Users\\ADMIN\\Downloads\\datasets_19_420_iris.csv")

# %%
iris.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
iris.shape
# Out:
# (150, 6)

# %%
iris.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
iris.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
iris['Species'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object>

# %%
iris.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
iris.hist(edgecolor='black', linewidth=1.2)
fig=plt.gcf()
fig.set_size_inches(20,12)
plt.show()

# %%
sns.countplot(x='Species',data=iris,palette='hls')

# %%
# check for outlairs

# %%
iris.boxplot(column=['SepalLengthCm'],grid = False)

# %%
iris.boxplot(column=['SepalWidthCm'],grid=False)

# %%
iris.boxplot(column=['PetalLengthCm'],grid=False)

# %%
iris.boxplot(column=['PetalWidthCm'],grid=False)

# %%
# check for corellstion value

# %%
iris.corr()
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %%
sns.pairplot(data=iris,hue='Species')

# %%
plt.figure(figsize=(7,4)) 
sns.heatmap(iris.corr(),annot=True,cmap='cubehelix_r')
plt.show()

# %%
#data cleansing

# %%
# cleansing of datse
removing of outlairs
# Out:
#   File "<ipython-input-25-9e34cea98813>", line 2
#     removing of outlairs
#               ^
# SyntaxError: invalid syntax

# %%
iris.SepalWidthCm.describe()
# Out:
# count    150.000000
# mean       3.054000
# std        0.433594
# min        2.000000
# 25%        2.800000
# 50%        3.000000
# 75%        3.300000
# max        4.400000
# Name: SepalWidthCm, dtype: float64

# %%
iris['SepalWidthCm']=iris['SepalWidthCm'].clip(2.100000,3.300000)

# %%
iris.boxplot(column=['SepalWidthCm'],grid=False)

# %%
del iris['Id']

# %%
iris.head(5)
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.3            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.3            1.4           0.2  Iris-setosa

# %%
# model building

# %%
x = iris[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]
y = iris['Species']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model1=DecisionTreeClassifier()

# %%
model1.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
model1.score(x_train,y_train)
# Out:
# 1.0

# %%
ypred=model1.predict(x_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,ypred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        11
# Iris-versicolor       0.88      0.88      0.88         8
#  Iris-virginica       0.91      0.91      0.91        11
#
#        accuracy                           0.93        30
#       macro avg       0.93      0.93      0.93        30
#    weighted avg       0.93      0.93      0.93        30

# %%
from sklearn import tree
tree.plot_tree(model1)
# Out:
# [Text(133.92000000000002, 199.32, 'X[3] <= 0.8\ngini = 0.666\nsamples = 120\nvalue = [39, 42, 39]'),
#  Text(100.44000000000001, 163.07999999999998, 'gini = 0.0\nsamples = 39\nvalue = [39, 0, 0]'),
#  Text(167.40000000000003, 163.07999999999998, 'X[3] <= 1.65\ngini = 0.499\nsamples = 81\nvalue = [0, 42, 39]'),
#  Text(66.96000000000001, 126.83999999999999, 'X[2] <= 4.95\ngini = 0.127\nsamples = 44\nvalue = [0, 41, 3]'),
#  Text(33.480000000000004, 90.6, 'gini = 0.0\nsamples = 40\nvalue = [0, 40, 0]'),
#  Text(100.44000000000001, 90.6, 'X[1] <= 2.75\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3]'),
#  Text(66.96000000000001, 54.359999999999985, 'X[2] <= 5.05\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(33.480000000000004, 18.119999999999976, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(100.44000000000001, 18.119999999999976, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(133.92000000000002, 54.359999999999985, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
# ...
